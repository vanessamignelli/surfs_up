# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
#create engine to connect to the SQLite databse later on
engine = create_engine("sqlite:///hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
# references the classes that were mapped in each table
# Base.classes gives us access to all the classes
# keys() references all the names of the classes
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
# to reference a specific class use Base.classes.<class name>
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# # Exploratory Climate Analysis

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results. 
#Starting from the last data point in the database. 
prev_year = dt.date(2017, 8, 23)

# Calculate the date one year from the last date in data set.
prev_year = dt.date(2017, 8, 23) - dt.timedelta(days=365)

# Perform a query to retrieve the data and precipitation scores
#create a variable to store results of the query
results = []

#add session to query database
results = session.query(Measurement.date, Measurement.prcp)

#filter out data we don't need that is older than a year
results = session.query(Measurement.date, Measurement.prcp).filter(Measurement.date >= prev_year)

#add all results from the query and put them in a list
results = session.query(Measurement.date, Measurement.prcp).filter(Measurement.date >= prev_year).all()

print(results)
# Out:
# [('2016-08-23', 0.0), ('2016-08-24', 0.08), ('2016-08-25', 0.08), ('2016-08-26', 0.0), ('2016-08-27', 0.0), ('2016-08-28', 0.01), ('2016-08-29', 0.0), ('2016-08-30', 0.0), ('2016-08-31', 0.13), ('2016-09-01', 0.0), ('2016-09-02', 0.0), ('2016-09-03', 0.0), ('2016-09-04', 0.03), ('2016-09-05', None), ('2016-09-06', None), ('2016-09-07', 0.05), ('2016-09-08', 0.0), ('2016-09-09', 0.03), ('2016-09-10', 0.0), ('2016-09-11', 0.05), ('2016-09-12', 0.0), ('2016-09-13', 0.02), ('2016-09-14', 1.32), ('2016-09-15', 0.42), ('2016-09-16', 0.06), ('2016-09-17', 0.05), ('2016-09-18', 0.0), ('2016-09-19', 0.0), ('2016-09-20', 0.0), ('2016-09-21', 0.0), ('2016-09-22', 0.02), ('2016-09-23', 0.0), ('2016-09-24', 0.0), ('2016-09-25', 0.0), ('2016-09-26', 0.06), ('2016-09-27', 0.02), ('2016-09-28', 0.0), ('2016-09-29', 0.0), ('2016-09-30', 0.0), ('2016-10-01', 0.0), ('2016-10-02', 0.0), ('2016-10-03', 0.0), ('2016-10-04', 0.0), ('2016-10-05', 0.0), ('2016-10-06', 0.0), ('2016-10-07', 0.0), ('2016-10-08'
# ...

# %%
# Save the query results as a Pandas DataFrame and set the index to the date column
#save results variable as one parameter and specify column names as the second parameter
df = pd.DataFrame(results, columns=['date', 'percipitation'])

# Sort the dataframe by date
df.set_index(df['date'], inplace=True)
# Out:
#                   date  percipitation
# date
# 2016-08-23  2016-08-23           0.00
# 2016-08-24  2016-08-24           0.08
# 2016-08-25  2016-08-25           0.08
# 2016-08-26  2016-08-26           0.00
# 2016-08-27  2016-08-27           0.00
# ...                ...            ...
# 2017-08-19  2017-08-19           0.09
# 2017-08-20  2017-08-20            NaN
# 2017-08-21  2017-08-21           0.56
# 2017-08-22  2017-08-22           0.50
# 2017-08-23  2017-08-23           0.45
#
# [2230 rows x 2 columns]

# %%
#print dataframe with index
print(df)
# Out:
#                   date  percipitation
# date
# 2016-08-23  2016-08-23           0.00
# 2016-08-24  2016-08-24           0.08
# 2016-08-25  2016-08-25           0.08
# 2016-08-26  2016-08-26           0.00
# 2016-08-27  2016-08-27           0.00
# ...                ...            ...
# 2017-08-19  2017-08-19           0.09
# 2017-08-20  2017-08-20            NaN
# 2017-08-21  2017-08-21           0.56
# 2017-08-22  2017-08-22           0.50
# 2017-08-23  2017-08-23           0.45
#
# [2230 rows x 2 columns]

# %%
#print dataframe without the index
#convert df to strings and then set the index to false
print(df.to_string(index=False))
# Out:
#        date  percipitation
#  2016-08-23           0.00
#  2016-08-24           0.08
#  2016-08-25           0.08
#  2016-08-26           0.00
#  2016-08-27           0.00
#  2016-08-28           0.01
#  2016-08-29           0.00
#  2016-08-30           0.00
#  2016-08-31           0.13
#  2016-09-01           0.00
#  2016-09-02           0.00
#  2016-09-03           0.00
#  2016-09-04           0.03
#  2016-09-05            NaN
#  2016-09-06            NaN
#  2016-09-07           0.05
#  2016-09-08           0.00
#  2016-09-09           0.03
#  2016-09-10           0.00
#  2016-09-11           0.05
#  2016-09-12           0.00
#  2016-09-13           0.02
#  2016-09-14           1.32
#  2016-09-15           0.42
#  2016-09-16           0.06
#  2016-09-17           0.05
#  2016-09-18           0.00
#  2016-09-19           0.00
#  2016-09-20           0.00
#  2016-09-21           0.00
#  2016-09-22           0.02
#  2016-09-23           0.00
#  2016-09-24           0.00
# ...

# %%
#sort the data by date with the index in chronological order
df = df.sort_index()
print(df.to_string(index=False))
# Out:
#        date  percipitation
#  2016-08-23           0.00
#  2016-08-23            NaN
#  2016-08-23           1.79
#  2016-08-23           0.05
#  2016-08-23           0.15
#  2016-08-23           0.70
#  2016-08-23           0.02
#  2016-08-24           0.08
#  2016-08-24           2.15
#  2016-08-24           2.28
#  2016-08-24            NaN
#  2016-08-24           1.45
#  2016-08-24           1.22
#  2016-08-24           2.15
#  2016-08-25           0.08
#  2016-08-25           0.00
#  2016-08-25           0.21
#  2016-08-25           0.06
#  2016-08-25           0.00
#  2016-08-25           0.11
#  2016-08-25           0.08
#  2016-08-26           0.03
#  2016-08-26           0.01
#  2016-08-26           0.00
#  2016-08-26           0.04
#  2016-08-26           0.02
#  2016-08-26           0.00
#  2016-08-27           0.18
#  2016-08-27           0.12
#  2016-08-27           0.00
#  2016-08-27           0.00
#  2016-08-27           0.02
#  2016-08-27            NaN
# ...

# %%
# Use Pandas Plotting with Matplotlib to plot the data
df.plot(figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
df.describe()
# Out:
#        percipitation
# count    2021.000000
# mean        0.177279
# std         0.461190
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.130000
# max         6.700000

# %%
# How many stations are available in this dataset?
#add func.count() to count the given dataset
#add .all() to return query as a list
session.query(func.count(Station.station)).all()
# Out:
# [(9)]

# %%
# What are the most active stations?
# List the stations and the counts in descending order.
session.query(Measurement.station, func.count(Measurement.station)).group_by(Measurement.station).order_by(func.count(Measurement.station).desc()).all()
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature most active station?
session.query(func.min(Measurement.tobs), func.max(Measurement.tobs), func.avg(Measurement.tobs)).filter(Measurement.station =='USC00519281').all()
# Out:
# [(54.0, 85.0, 71.66378066378067)]

# %%
# Choose the station with the highest number of temperature observations.
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram
results = session.query(Measurement.tobs).filter(Measurement.station == 'USC00519281').filter(Measurement.date >= prev_year).all()
print(results)
# Out:
# [(77.0,), (77.0,), (80.0,), (80.0,), (75.0,), (73.0,), (78.0,), (77.0,), (78.0,), (80.0,), (80.0,), (78.0,), (78.0,), (78.0,), (73.0,), (74.0,), (80.0,), (79.0,), (77.0,), (80.0,), (76.0,), (79.0,), (75.0,), (79.0,), (78.0,), (79.0,), (78.0,), (78.0,), (76.0,), (74.0,), (77.0,), (78.0,), (79.0,), (79.0,), (77.0,), (80.0,), (78.0,), (78.0,), (78.0,), (77.0,), (79.0,), (79.0,), (79.0,), (79.0,), (75.0,), (76.0,), (73.0,), (72.0,), (71.0,), (77.0,), (79.0,), (78.0,), (79.0,), (77.0,), (79.0,), (77.0,), (78.0,), (78.0,), (78.0,), (78.0,), (77.0,), (74.0,), (75.0,), (76.0,), (73.0,), (76.0,), (74.0,), (77.0,), (76.0,), (76.0,), (74.0,), (75.0,), (75.0,), (75.0,), (75.0,), (71.0,), (63.0,), (70.0,), (68.0,), (67.0,), (77.0,), (74.0,), (77.0,), (76.0,), (76.0,), (75.0,), (76.0,), (75.0,), (73.0,), (75.0,), (73.0,), (75.0,), (74.0,), (75.0,), (74.0,), (75.0,), (73.0,), (75.0,), (73.0,), (73.0,), (74.0,), (70.0,), (72.0,), (70.0,), (67.0,), (67.0,), (69.0,), (70.0,), (68.0,), (69.0,), (69.0,)
# ...

# %%
#put temperature results into a dataframe and print without index
df = pd.DataFrame(results, columns = ['tobs'])
print(df.to_string(index=False))
# Out:
#  tobs
#  77.0
#  77.0
#  80.0
#  80.0
#  75.0
#  73.0
#  78.0
#  77.0
#  78.0
#  80.0
#  80.0
#  78.0
#  78.0
#  78.0
#  73.0
#  74.0
#  80.0
#  79.0
#  77.0
#  80.0
#  76.0
#  79.0
#  75.0
#  79.0
#  78.0
#  79.0
#  78.0
#  78.0
#  76.0
#  74.0
#  77.0
#  78.0
#  79.0
#  79.0
#  77.0
#  80.0
#  78.0
#  78.0
#  78.0
#  77.0
#  79.0
#  79.0
#  79.0
#  79.0
#  75.0
#  76.0
#  73.0
#  72.0
#  71.0
#  77.0
#  79.0
#  78.0
#  79.0
#  77.0
#  79.0
#  77.0
#  78.0
#  78.0
#  78.0
#  78.0
#  77.0
#  74.0
#  75.0
#  76.0
#  73.0
#  76.0
#  74.0
#  77.0
#  76.0
#  76.0
#  74.0
#  75.0
#  75.0
#  75.0
#  75.0
#  71.0
#  63.0
#  70.0
#  68.0
#  67.0
#  77.0
#  74.0
#  77.0
#  76.0
#  76.0
#  75.0
#  76.0
#  75.0
#  73.0
#  75.0
#  73.0
#  75.0
#  74.0
#  75.0
#  74.0
#  75.0
#  73.0
#  75.0
#  73.0
#  73.0
#  74.0
#  70.0
#  72.0
#  70.0
#  67.0
#  67.0
#  69.0
#  70.0
#  68.0
#  69.0
#  69.0
#  66.0
#  65.0
#  68.0
#  62.0
#  75.0
#  70.0
#  69.0
#  76.0
#  76.0
#  74.0
#  73.0
#  71.0
#  74.0
# ...

# %%
#plot the data into a histogram with 12 bins
df.plot.hist(bins=12)
plt.tight_layout()

# %%
# Write a function called `calc_temps` that will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates

# %% [markdown]
# # Challenge

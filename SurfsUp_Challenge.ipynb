# %%
# Dependencies
import numpy as np
import pandas as pd

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# ## D1: Determine the Summary Statistics for June

# %%
# 1. Import the sqlalchemy extract function.
from sqlalchemy import extract

# 2. Write a query that filters the Measurement table to retrieve the temperatures for the month of June. 
june_results = session.query(Measurement.date, Measurement.tobs).filter(extract('month', Measurement.date) == '06').all()

# %%
#  3. Convert the June temperatures to a list.
june_temps = []
x = 0
for temp in june_results:
    temp = june_results[x][1]
    june_temps.append(temp)
    x += 1
june_temps
# Out:
# [78.0,
#  76.0,
#  78.0,
#  76.0,
#  77.0,
#  78.0,
#  77.0,
#  78.0,
#  78.0,
#  79.0,
#  78.0,
#  78.0,
#  78.0,
#  77.0,
#  78.0,
#  78.0,
#  77.0,
#  77.0,
#  82.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  77.0,
#  76.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  77.0,
#  78.0,
#  73.0,
#  70.0,
#  76.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  78.0,
#  77.0,
#  77.0,
#  78.0,
#  78.0,
#  77.0,
#  78.0,
#  78.0,
#  75.0,
#  76.0,
#  76.0,
#  77.0,
#  78.0,
#  76.0,
#  77.0,
#  75.0,
#  77.0,
#  76.0,
#  76.0,
#  75.0,
#  77.0,
#  77.0,
#  76.0,
#  78.0,
#  77.0,
#  76.0,
#  77.0,
#  76.0,
#  76.0,
#  77.0,
#  77.0,
#  78.0,
#  77.0,
#  77.0,
#  77.0,
#  76.0,
#  75.0,
#  76.0,
#  76.0,
#  77.0,
#  76.0,
#  73.0,
#  73.0,
#  75.0,
#  77.0,
#  76.0,
#  77.0,
#  79.0,
#  78.0,
#  79.0,
#  78.0,
#  78.0,
#  79.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  78.0,
#  77.0,
#  76.0,
#  78.0,
#  78.0,
#  77.0,
#  78.0,
#  78.0,
#  73.0,
#  76.0,
#  77.0,
#  75.0,
#  76.0,
#  74.0,
# ...

# %%
# 4. Create a DataFrame from the list of temperatures for the month of June.
june_temp_df = pd.DataFrame(june_temps, columns=['June Temps'])
june_temp_df.head()
# Out:
#    June Temps
# 0        78.0
# 1        76.0
# 2        78.0
# 3        76.0
# 4        77.0

# %%
# 5. Calculate and print out the summary statistics for the June temperature DataFrame.
june_temp_df.describe()
# Out:
#         June Temps
# count  1700.000000
# mean     74.944118
# std       3.257417
# min      64.000000
# 25%      73.000000
# 50%      75.000000
# 75%      77.000000
# max      85.000000

# %% [markdown]
# ## D2: Determine the Summary Statistics for December

# %%
# 6. Write a query that filters the Measurement table to retrieve the temperatures for the month of December.
dec_results = session.query(Measurement.date, Measurement.tobs).filter(extract('month', Measurement.date) == '12').all()
dec_results
# Out:
# [('2010-12-01', 76.0),
#  ('2010-12-03', 74.0),
#  ('2010-12-04', 74.0),
#  ('2010-12-06', 64.0),
#  ('2010-12-07', 64.0),
#  ('2010-12-08', 67.0),
#  ('2010-12-09', 77.0),
#  ('2010-12-10', 66.0),
#  ('2010-12-11', 69.0),
#  ('2010-12-12', 68.0),
#  ('2010-12-13', 68.0),
#  ('2010-12-14', 71.0),
#  ('2010-12-15', 74.0),
#  ('2010-12-16', 67.0),
#  ('2010-12-17', 66.0),
#  ('2010-12-18', 69.0),
#  ('2010-12-19', 71.0),
#  ('2010-12-23', 70.0),
#  ('2010-12-24', 70.0),
#  ('2010-12-26', 74.0),
#  ('2010-12-27', 74.0),
#  ('2010-12-28', 71.0),
#  ('2010-12-29', 75.0),
#  ('2010-12-30', 75.0),
#  ('2010-12-31', 72.0),
#  ('2011-12-01', 69.0),
#  ('2011-12-02', 68.0),
#  ('2011-12-03', 73.0),
#  ('2011-12-04', 74.0),
#  ('2011-12-05', 73.0),
#  ('2011-12-06', 73.0),
#  ('2011-12-07', 73.0),
#  ('2011-12-08', 73.0),
#  ('2011-12-09', 71.0),
#  ('2011-12-10', 73.0),
#  ('2011-12-11', 73.0),
#  ('2011-12-12', 77.0),
#  ('2011-12-13', 72.0),
#  ('2011-12-14', 71.0),
#  ('2011-12-15', 73.0),
# ...

# %%
# 7. Convert the December temperatures to a list.
dec_temps = []
x = 0
for temp in dec_results:
    temp = dec_results[x][1]
    dec_temps.append(temp)
    x += 1
dec_temps
# Out:
# [76.0,
#  74.0,
#  74.0,
#  64.0,
#  64.0,
#  67.0,
#  77.0,
#  66.0,
#  69.0,
#  68.0,
#  68.0,
#  71.0,
#  74.0,
#  67.0,
#  66.0,
#  69.0,
#  71.0,
#  70.0,
#  70.0,
#  74.0,
#  74.0,
#  71.0,
#  75.0,
#  75.0,
#  72.0,
#  69.0,
#  68.0,
#  73.0,
#  74.0,
#  73.0,
#  73.0,
#  73.0,
#  73.0,
#  71.0,
#  73.0,
#  73.0,
#  77.0,
#  72.0,
#  71.0,
#  73.0,
#  70.0,
#  73.0,
#  69.0,
#  74.0,
#  72.0,
#  71.0,
#  72.0,
#  72.0,
#  70.0,
#  73.0,
#  73.0,
#  72.0,
#  73.0,
#  73.0,
#  72.0,
#  63.0,
#  65.0,
#  71.0,
#  76.0,
#  70.0,
#  76.0,
#  69.0,
#  69.0,
#  69.0,
#  74.0,
#  76.0,
#  74.0,
#  73.0,
#  73.0,
#  74.0,
#  73.0,
#  73.0,
#  73.0,
#  74.0,
#  74.0,
#  71.0,
#  73.0,
#  72.0,
#  64.0,
#  66.0,
#  73.0,
#  72.0,
#  65.0,
#  64.0,
#  69.0,
#  68.0,
#  77.0,
#  71.0,
#  71.0,
#  69.0,
#  68.0,
#  68.0,
#  69.0,
#  70.0,
#  72.0,
#  76.0,
#  75.0,
#  69.0,
#  71.0,
#  71.0,
#  71.0,
#  68.0,
#  65.0,
#  70.0,
#  69.0,
#  69.0,
#  71.0,
#  67.0,
#  73.0,
#  74.0,
#  73.0,
# ...

# %%
# 8. Create a DataFrame from the list of temperatures for the month of December. 
dec_temps_df = pd.DataFrame(dec_temps, columns=['December Temps'])
dec_temps_df.head()
# Out:
#    December Temps
# 0            76.0
# 1            74.0
# 2            74.0
# 3            64.0
# 4            64.0

# %%
# 9. Calculate and print out the summary statistics for the Decemeber temperature DataFrame.
dec_temps_df.describe()
# Out:
#        December Temps
# count     1517.000000
# mean        71.041529
# std          3.745920
# min         56.000000
# 25%         69.000000
# 50%         71.000000
# 75%         74.000000
# max         83.000000

# %%
#create a query for June precipitation
june_prcp_results = session.query(Measurement.date, Measurement.prcp).filter(extract('month', Measurement.date) == '06').all()
june_prcp_results
# Out:
# [('2010-06-01', 0.0),
#  ('2010-06-02', 0.01),
#  ('2010-06-03', 0.0),
#  ('2010-06-04', 0.0),
#  ('2010-06-05', 0.0),
#  ('2010-06-06', 0.0),
#  ('2010-06-07', 0.0),
#  ('2010-06-08', 0.0),
#  ('2010-06-09', 0.0),
#  ('2010-06-10', 0.0),
#  ('2010-06-11', 0.0),
#  ('2010-06-12', 0.0),
#  ('2010-06-13', 0.0),
#  ('2010-06-14', 0.0),
#  ('2010-06-15', 0.0),
#  ('2010-06-16', 0.0),
#  ('2010-06-17', 0.0),
#  ('2010-06-18', 0.0),
#  ('2010-06-19', 0.0),
#  ('2010-06-20', 0.0),
#  ('2010-06-21', 0.0),
#  ('2010-06-22', 0.0),
#  ('2010-06-23', 0.0),
#  ('2010-06-24', 0.0),
#  ('2010-06-25', 0.0),
#  ('2010-06-26', 0.02),
#  ('2010-06-27', 0.0),
#  ('2010-06-28', 0.0),
#  ('2010-06-29', 0.0),
#  ('2010-06-30', 0.0),
#  ('2011-06-01', 0.07),
#  ('2011-06-02', 0.0),
#  ('2011-06-03', 0.56),
#  ('2011-06-04', 0.89),
#  ('2011-06-05', 0.0),
#  ('2011-06-06', 0.0),
#  ('2011-06-07', 0.0),
#  ('2011-06-08', 0.03),
#  ('2011-06-09', 0.01),
#  ('2011-06-10', 0.0),
#  ('2011-06-11', 0.0),
# ...

# %%
#transform june results into a dataframe
june_prcp_df = pd.DataFrame(june_prcp_results, columns=['date', 'percipitaion'])
june_prcp_df.head()
# Out:
#          date  percipitaion
# 0  2010-06-01          0.00
# 1  2010-06-02          0.01
# 2  2010-06-03          0.00
# 3  2010-06-04          0.00
# 4  2010-06-05          0.00

# %%
#get summary statistics for June precipitation
june_prcp_df.describe()
# Out:
#        percipitaion
# count   1574.000000
# mean       0.136360
# std        0.335731
# min        0.000000
# 25%        0.000000
# 50%        0.020000
# 75%        0.120000
# max        4.430000

# %%
#create a query for December precipitation
dec_prcp_results = session.query(Measurement.date, Measurement.prcp).filter(extract('month', Measurement.date) == '12').all()
dec_prcp_results
# Out:
# [('2010-12-01', 0.04),
#  ('2010-12-03', 0.0),
#  ('2010-12-04', 0.0),
#  ('2010-12-06', 0.0),
#  ('2010-12-07', 0.0),
#  ('2010-12-08', 0.0),
#  ('2010-12-09', 0.0),
#  ('2010-12-10', 1.58),
#  ('2010-12-11', 0.77),
#  ('2010-12-12', 0.0),
#  ('2010-12-13', 0.0),
#  ('2010-12-14', 0.0),
#  ('2010-12-15', 0.0),
#  ('2010-12-16', 0.0),
#  ('2010-12-17', 0.0),
#  ('2010-12-18', 0.0),
#  ('2010-12-19', 1.4),
#  ('2010-12-23', 0.0),
#  ('2010-12-24', 0.0),
#  ('2010-12-26', None),
#  ('2010-12-27', 0.13),
#  ('2010-12-28', 0.55),
#  ('2010-12-29', 0.06),
#  ('2010-12-30', 0.01),
#  ('2010-12-31', 0.0),
#  ('2011-12-01', 0.03),
#  ('2011-12-02', 0.08),
#  ('2011-12-03', 0.0),
#  ('2011-12-04', 0.0),
#  ('2011-12-05', 0.0),
#  ('2011-12-06', 0.0),
#  ('2011-12-07', 0.0),
#  ('2011-12-08', 0.0),
#  ('2011-12-09', 0.13),
#  ('2011-12-10', 0.07),
#  ('2011-12-11', 0.07),
#  ('2011-12-12', 0.08),
#  ('2011-12-13', 0.4),
#  ('2011-12-14', 0.7),
#  ('2011-12-15', 0.0),
#  ('2011-12-16', 0.01),
# ...

# %%
#transform December results into a dataframe
dec_prcp_df = pd.DataFrame(dec_prcp_results, columns=['date', 'percipitaion'])
dec_prcp_df.head()
# Out:
#          date  percipitaion
# 0  2010-12-01          0.04
# 1  2010-12-03          0.00
# 2  2010-12-04          0.00
# 3  2010-12-06          0.00
# 4  2010-12-07          0.00

# %%
#get summary statistics for December precipitation
dec_prcp_df.describe()
# Out:
#        percipitaion
# count   1405.000000
# mean       0.216819
# std        0.541399
# min        0.000000
# 25%        0.000000
# 50%        0.030000
# 75%        0.150000
# max        6.420000
